# %%
import sys
# !{sys.executable} -m pip install pandas
import import_ipynb
import glassdoor_scrapper as gs
import pandas as pd

path = '/usr/bin/safaridriver'

df = gs.get_jobs('data_scientist',10,False,path,15)

display(df)
# Out:
# ...
#  x out failed
# Progress: 0/10
# Progress: 1/10
# Progress: 2/10
# Progress: 3/10
# Progress: 4/10
# Progress: 5/10
# Progress: 6/10
# Progress: 7/10
# Progress: 8/10
# Progress: 9/10
# Progress: 10/10
#           Job Title               Salary Estimate  \
# 0  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 1  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 2  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 3  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 4  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 5  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 6  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 7  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 8  Data Scientist 2  $52K - $95K (Glassdoor est.)
# 9  Data Scientist 2  $52K - $95K (Glassdoor est.)
#
#                                      Job Description Rating Company Name  \
# 0  Description\nDigital Health and Analytics with...    3.9    Humana3.9
# ...
